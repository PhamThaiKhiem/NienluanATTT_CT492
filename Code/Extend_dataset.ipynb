# %%
# --- Cài thư viện ---
# !pip install ctgan --quiet
# !pip install pandas --quiet

# --- Mount Google Drive ---
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import random
from ctgan import CTGAN
import os

# --- Cấu hình ---
input_csv = "/content/drive/MyDrive/consolidated_traffic_data.csv"
output_dir = "/content/drive/MyDrive/synthetic_per_label_1M5"
min_total = 108000
max_total = 113000
random_seed = 42

os.makedirs(output_dir, exist_ok=True)
random.seed(random_seed)

# --- Đọc dataset ---
df = pd.read_csv(input_csv)

print("Các cột có sẵn trong DataFrame:")
print(df.columns)

# --- Thống kê số dòng mỗi nhãn ---
label_counts = df['traffic_type'].value_counts()
print("Số dòng hiện tại mỗi nhãn:")
print(label_counts)

# Danh sách các cột nên là số không âm
non_negative_columns = [
    'duration', 'total_fiat', 'total_biat', 'min_fiat', 'min_biat',
    'max_fiat', 'max_biat', 'mean_fiat', 'mean_biat', 'flowPktsPerSecond',
    'flowBytesPerSecond', 'min_flowiat', 'max_flowiat', 'mean_flowiat',
    'std_flowiat', 'min_active', 'mean_active', 'max_active', 'std_active',
    'min_idle', 'mean_idle', 'max_idle', 'std_idle'
]

# --- Sinh dữ liệu mới cho mỗi nhãn ---
for label, count in label_counts.items():
    target_total = random.randint(min_total, max_total)
    rows_to_generate = max(target_total - count, 0)

    print(f"\nNhãn '{label}': hiện có {count} dòng, muốn tổng ~{target_total} dòng, cần sinh thêm {rows_to_generate} dòng.")

    df_label = df[df['traffic_type'] == label]

    if rows_to_generate > 0:
        # Fit CTGAN trên dữ liệu nhãn này, chỉ định 'traffic_type' là cột rời rạc
        model = CTGAN(epochs=300, batch_size=500)
        model.fit(df_label, discrete_columns=['traffic_type'])

        # Sinh dữ liệu mới
        synthetic_label_data = model.sample(rows_to_generate)

        # Xử lý hậu kỳ: Đảm bảo các cột không âm
        for col in non_negative_columns:
            if col in synthetic_label_data.columns:
                synthetic_label_data[col] = synthetic_label_data[col].apply(lambda x: max(x, 0))
    else:
        synthetic_label_data = pd.DataFrame(columns=df.columns)

    # Gộp dữ liệu gốc + dữ liệu mới
    df_total_label = pd.concat([df_label, synthetic_label_data], ignore_index=True)

    # Xuất CSV riêng
    output_csv = os.path.join(output_dir, f"{label}_synthetic.csv")
    df_total_label.to_csv(output_csv, index=False)

    print(f"Xuất xong {len(df_total_label)} dòng vào {output_csv}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.9 MB/s eta 0:00:00
# Mounted at /content/drive
# Các cột có sẵn trong DataFrame:
# Index(['duration', 'total_fiat', 'total_biat', 'min_fiat', 'min_biat',
#        'max_fiat', 'max_biat', 'mean_fiat', 'mean_biat', 'flowPktsPerSecond',
#        'flowBytesPerSecond', 'min_flowiat', 'max_flowiat', 'mean_flowiat',
#        'std_flowiat', 'min_active', 'mean_active', 'max_active', 'std_active',
#        'min_idle', 'mean_idle', 'max_idle', 'std_idle', 'traffic_type'],
#       dtype='object')
# Số dòng hiện tại mỗi nhãn:
# traffic_type
# BROWSING         10000
# VPN-BROWSING      9982
# VOIP              6436
# VPN-VOIP          5549
# VPN-FT            4616
# P2P               3987
# FT                3348
# VPN-CHAT          2708
# VPN-P2P           2486
# CHAT              2469
# VPN-MAIL          2432
# MAIL              1307
# STREAMING         1163
# VPN-STREAMING     1113
# Name: count, dtype: int64
#
# Nhãn 'BROWSING': hiện có 10000 dòng, muốn tổng ~108912 dòng, cần sinh thêm 98912 dòng.
# Xuất xong 108912 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/BROWSING_synthetic.csv
#
# Nhãn 'VPN-BROWSING': hiện có 9982 dòng, muốn tổng ~108204 dòng, cần sinh thêm 98222 dòng.
# Xuất xong 108204 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/VPN-BROWSING_synthetic.csv
#
# Nhãn 'VOIP': hiện có 6436 dòng, muốn tổng ~110253 dòng, cần sinh thêm 103817 dòng.
# Xuất xong 110253 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/VOIP_synthetic.csv
#
# Nhãn 'VPN-VOIP': hiện có 5549 dòng, muốn tổng ~110006 dòng, cần sinh thêm 104457 dòng.
# Xuất xong 110006 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/VPN-VOIP_synthetic.csv
#
# Nhãn 'VPN-FT': hiện có 4616 dòng, muốn tổng ~109828 dòng, cần sinh thêm 105212 dòng.
# Xuất xong 109828 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/VPN-FT_synthetic.csv
#
# Nhãn 'P2P': hiện có 3987 dòng, muốn tổng ~109143 dòng, cần sinh thêm 105156 dòng.
# Xuất xong 109143 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/P2P_synthetic.csv
#
# Nhãn 'FT': hiện có 3348 dòng, muốn tổng ~108839 dòng, cần sinh thêm 105491 dòng.
# Xuất xong 108839 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/FT_synthetic.csv
#
# Nhãn 'VPN-CHAT': hiện có 2708 dòng, muốn tổng ~112467 dòng, cần sinh thêm 109759 dòng.
# Xuất xong 112467 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/VPN-CHAT_synthetic.csv
#
# Nhãn 'VPN-P2P': hiện có 2486 dòng, muốn tổng ~108712 dòng, cần sinh thêm 106226 dòng.
# Xuất xong 108712 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/VPN-P2P_synthetic.csv
#
# Nhãn 'CHAT': hiện có 2469 dòng, muốn tổng ~112837 dòng, cần sinh thêm 110368 dòng.
# Xuất xong 112837 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/CHAT_synthetic.csv
#
# Nhãn 'VPN-MAIL': hiện có 2432 dòng, muốn tổng ~111456 dòng, cần sinh thêm 109024 dòng.
# Xuất xong 111456 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/VPN-MAIL_synthetic.csv
#
# Nhãn 'MAIL': hiện có 1307 dòng, muốn tổng ~108260 dòng, cần sinh thêm 106953 dòng.
# Xuất xong 108260 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/MAIL_synthetic.csv
#
# Nhãn 'STREAMING': hiện có 1163 dòng, muốn tổng ~108244 dòng, cần sinh thêm 107081 dòng.
# Xuất xong 108244 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/STREAMING_synthetic.csv
#
# Nhãn 'VPN-STREAMING': hiện có 1113 dòng, muốn tổng ~108767 dòng, cần sinh thêm 107654 dòng.
# Xuất xong 108767 dòng vào /content/drive/MyDrive/synthetic_per_label_1M5/VPN-STREAMING_synthetic.csv
